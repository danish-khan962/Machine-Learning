# %% [raw]
# PANDAS - useful for data processing and analysis
#
# Pandas Dataframes - Pandas Dataframe is two-dimensional tabular data structure with labeled axes (rows & columns)

# %%
#Installing pandas library
# !pip install pandas

# %%
#Importing pandas 
import pandas as pd
import numpy as np

# %% [raw]
# Creating a Pandas DataFrame

# %%
#Creating a pandas dataframe
stats = {
    "name":['Danish','Sam','Bob','Amy'],
    "age":[20,19,18,20],
    "grades":['A','C','A','A']
}
df = pd.DataFrame(stats)
print(df)
type(df)
# Out:
#      name  age grades
# 0  Danish   20      A
# 1     Sam   19      C
# 2     Bob   18      A
# 3     Amy   20      A
# pandas.core.frame.DataFrame

# %%
 #Reading a CSV file and converting it into DataFrame
boston_dataset = pd.read_csv("BostonHousing.csv")
boston_df = pd.DataFrame(boston_dataset)
print(boston_df)
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#First 5 rows of dataset
print(boston_df.head())
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
#shape of a dataframe
boston_df.shape
# Out:
# (506, 14)

# %%
#Last 5 rows of dataset
print(boston_df.tail())
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
#Loading the data from a excel file to a Pandas DataFrame:
# pd.read_excel('file path')

# %% [raw]
# Exporting a DataFrame to a csv file

# %%
diabetes_data = pd.read_csv('diabetes.csv')
diabetes_df = pd.DataFrame(diabetes_data) #converted into pandas dataframe

#now converting back dataframe into csv
diabetes_csv = diabetes_df.to_csv('diabetes.csv')
print(diabetes_csv)
# Out:
# None

# %%
#Exporting the Pandas DataFrame to an excel file:
#df.to_excel('filename')

# %%
#Creating a DataFrame with random values
random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.649342  0.343318  0.355261  0.462549  0.382420  0.170773  0.430580
# 1  0.855501  0.058031  0.170933  0.816328  0.483196  0.892640  0.554683
# 2  0.945031  0.463504  0.232370  0.243335  0.598739  0.876577  0.214870
# 3  0.383038  0.845394  0.781207  0.796092  0.677033  0.559557  0.591354
# 4  0.672383  0.872208  0.071595  0.224120  0.750129  0.117490  0.300466
#
#           7         8         9
# 0  0.472466  0.727088  0.233254
# 1  0.761892  0.246902  0.212403
# 2  0.445268  0.512864  0.845501
# 3  0.203986  0.208208  0.284705
# 4  0.192163  0.941899  0.711195

# %%
random_df.shape
# Out:
# (20, 10)

# %% [raw]
# Inspecting a DataFrame

# %%
#Inspection of Boston DataFrame

# %%
#Finding number of rows and columns 
boston_df.shape
# Out:
# (506, 14)

# %%
#first 5 rows in a DataFrame
boston_df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
#last 5 rows in a DataFrame
boston_df.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
#Informations about the DataFrame
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
#finding the number of missing values in a DataFrame
boston_df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
#Diabetes DataFrame
diabetes_df.head()
# Out:
#    Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0           0            6      148             72             35        0
# 1           1            1       85             66             29        0
# 2           2            8      183             64              0        0
# 3           3            1       89             66             23       94
# 4           4            0      137             40             35      168
#
#     BMI  DiabetesPedigreeFunction  Age  Outcome
# 0  33.6                     0.627   50        1
# 1  26.6                     0.351   31        0
# 2  23.3                     0.672   32        1
# 3  28.1                     0.167   21        0
# 4  43.1                     2.288   33        1

# %%
#counting the values based on the labels
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
#group the values based on the mean
diabetes_df.groupby('Outcome').mean()
# Out:
#          Unnamed: 0  Pregnancies     Glucose  BloodPressure  SkinThickness  \
# Outcome
# 0        390.834000     3.298000  109.980000      68.184000      19.664000
# 1        369.817164     4.865672  141.257463      70.824627      22.164179
#
#             Insulin        BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0         68.792000  30.304200                  0.429734  31.190000
# 1        100.335821  35.142537                  0.550500  37.067164

# %% [raw]
# Stasticial Measures

# %%
#count the number of values in each column
boston_df.count()
# Out:
# crim       506
# zn         506
# indus      506
# chas       506
# nox        506
# rm         506
# age        506
# dis        506
# rad        506
# tax        506
# ptratio    506
# b          506
# lstat      506
# medv       506
# dtype: int64

# %%
#mean vaue -> column wise
boston_df.mean()
# Out:
# crim         3.613524
# zn          11.363636
# indus       11.136779
# chas         0.069170
# nox          0.554695
# rm           6.284634
# age         68.574901
# dis          3.795043
# rad          9.549407
# tax        408.237154
# ptratio     18.455534
# b          356.674032
# lstat       12.653063
# medv        22.532806
# dtype: float64

# %%
#standard deviation -> column wise
boston_df.std()
# Out:
# crim         8.601545
# zn          23.322453
# indus        6.860353
# chas         0.253994
# nox          0.115878
# rm           0.702617
# age         28.148861
# dis          2.105710
# rad          8.707259
# tax        168.537116
# ptratio      2.164946
# b           91.294864
# lstat        7.141062
# medv         9.197104
# dtype: float64

# %%
#minimun value in each column
boston_df.min()
# Out:
# crim         0.00632
# zn           0.00000
# indus        0.46000
# chas         0.00000
# nox          0.38500
# rm           3.56100
# age          2.90000
# dis          1.12960
# rad          1.00000
# tax        187.00000
# ptratio     12.60000
# b            0.32000
# lstat        1.73000
# medv         5.00000
# dtype: float64

# %%
#maximum value in each column
boston_df.max()
# Out:
# crim        88.9762
# zn         100.0000
# indus       27.7400
# chas         1.0000
# nox          0.8710
# rm           8.7800
# age        100.0000
# dis         12.1265
# rad         24.0000
# tax        711.0000
# ptratio     22.0000
# b          396.9000
# lstat       37.9700
# medv        50.0000
# dtype: float64

# %%
#All the statistical measures in one go
boston_df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# Manipulating a DataFrame

# %%
#add a column to a DataFrame
#boston_df['Price'] = boston_dataset.ATTRIBUTE_NAME

# %%
#removing a row
boston_df.drop(index=0, axis=0)
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 1    0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729  0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237  0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905  0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 5    0.02985  0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222     18.7
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# ...

# %%
#removing a column
boston_df.drop(columns='dis', axis=1)
# Out:
#         crim    zn  indus  chas    nox     rm   age  rad  tax  ptratio  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2    1  296     15.3
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9    2  242     17.8
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1    2  242     17.8
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8    3  222     18.7
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2    3  222     18.7
# ..       ...   ...    ...   ...    ...    ...   ...  ...  ...      ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1    1  273     21.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7    1  273     21.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0    1  273     21.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3    1  273     21.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8    1  273     21.0
#
#           b  lstat  medv
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# 2    392.83   4.03  34.7
# ...

# %%
#locating a row using the index value
boston_df.iloc[2]
# Out:
# crim         0.02729
# zn           0.00000
# indus        7.07000
# chas         0.00000
# nox          0.46900
# rm           7.18500
# age         61.10000
# dis          4.96710
# rad          2.00000
# tax        242.00000
# ptratio     17.80000
# b          392.83000
# lstat        4.03000
# medv        34.70000
# Name: 2, dtype: float64

# %%
#locating a column 
boston_df.iloc[:,0]   #first column
boston_df.iloc[:,1]   #second column
boston_df.iloc[:,2]   #third column
boston_df.iloc[:,-1]  #last column
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %% [raw]
# CORRELATION:  relationship b/w variables [columns]
#     1. Positive correlation ->  [one variable increases , other also increases]
#     2. Negative correlation ->  [one variabl increases , bu the other decreases]

# %%
boston_df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...
