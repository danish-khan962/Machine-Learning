# %%
#Importing dependecies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [raw]
# Data collection and preprocessing

# %%
#Data collection and preprocessing

# %%
#loading the dataset and coverting it from csv file to pandas DataFrame
diabetes_dataset = pd.read_csv('diabetes.csv')
diabetes_df = pd.DataFrame(diabetes_dataset)

# %%
diabetes_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Pregnancies  Glucose  BloodPressure  \
# 0             0           0            6      148             72
# 1             1           1            1       85             66
# 2             2           2            8      183             64
# 3             3           3            1       89             66
# 4             4           4            0      137             40
#
#    SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0             35        0  33.6                     0.627   50        1
# 1             29        0  26.6                     0.351   31        0
# 2              0        0  23.3                     0.672   32        1
# 3             23       94  28.1                     0.167   21        0
# 4             35      168  43.1                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 11)

# %%
diabetes_df.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0  Pregnancies     Glucose  BloodPressure  \
# count    768.000000  768.000000   768.000000  768.000000     768.000000
# mean     383.500000  383.500000     3.845052  120.894531      69.105469
# std      221.846794  221.846794     3.369578   31.972618      19.355807
# min        0.000000    0.000000     0.000000    0.000000       0.000000
# 25%      191.750000  191.750000     1.000000   99.000000      62.000000
# 50%      383.500000  383.500000     3.000000  117.000000      72.000000
# 75%      575.250000  575.250000     6.000000  140.250000      80.000000
# max      767.000000  767.000000    17.000000  199.000000     122.000000
#
#        SkinThickness     Insulin         BMI  DiabetesPedigreeFunction  \
# count     768.000000  768.000000  768.000000                768.000000
# mean       20.536458   79.799479   31.992578                  0.471876
# std        15.952218  115.244002    7.884160                  0.331329
# min         0.000000    0.000000    0.000000                  0.078000
# 25%         0.000000    0.000000   27.300000                  0.243750
# 50%        23.000000   30.500000   32.000000                  0.372500
# 75%        32.000000  127.250000   36.600000                  0.626250
# max        99.000000  846.000000   67.100000                  2.420000
#
#               Age     Outcome
# count  768.000000  768.000000
# mean    33.240885    0.348958
# std     11.760232    0.476951
# min     21.000000    0.000000
# 25%     24.000000    0.000000
# 50%     29.000000    0.000000
# 75%     41.000000    1.000000
# max     81.000000    1.000000

# %% [raw]
# Separating Features and outcomes

# %%
#Separating Features and outcomes
X = diabetes_df.drop(columns='Outcome', axis=1)
Y = diabetes_df['Outcome']

# %%
X
# Out:
#      Unnamed: 0.1  Unnamed: 0  Pregnancies  Glucose  BloodPressure  \
# 0               0           0            6      148             72
# 1               1           1            1       85             66
# 2               2           2            8      183             64
# 3               3           3            1       89             66
# 4               4           4            0      137             40
# ..            ...         ...          ...      ...            ...
# 763           763         763           10      101             76
# 764           764         764            2      122             70
# 765           765         765            5      121             72
# 766           766         766            1      126             60
# 767           767         767            1       93             70
#
#      SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age
# 0               35        0  33.6                     0.627   50
# 1               29        0  26.6                     0.351   31
# 2                0        0  23.3                     0.672   32
# 3               23       94  28.1                     0.167   21
# 4               35      168  43.1                     2.288   33
# ..             ...      ...   ...                       ...  ...
# 763             48      180  32.9                     0.171   63
# 764             27        0  36.8                     0.340   27
# 765             23      112  26.2                     0.245   30
# 766              0        0  30.1                     0.349   47
# 767             31        0  30.4                     0.315   23
#
# [768 rows x 10 columns]

# %%
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
#0-> Non-diabeteic
#1-> Diabetic

# %% [raw]
# DATA STANDARDIZATION

# %%
#DATA STANDARDIZATION

# %%
scaler = StandardScaler()

# %%
standardized_data = scaler.fit_transform(X)

# %%
standardized_data
# Out:
# array([[-1.729797  , -1.729797  ,  0.63994726, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-1.72528645, -1.72528645, -0.84488505, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [-1.72077589, -1.72077589,  1.23388019, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 1.72077589,  1.72077589,  0.3429808 , ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [ 1.72528645,  1.72528645, -0.84488505, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [ 1.729797  ,  1.729797  , -0.84488505, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [raw]
# SPLITTING THE DATASET INTO TRAINING DATA AND TESTING DATA

# %%
#SPLITTING THE DATASET INTO TRAINING DATA AND TESTING DATA

# %%
X_train , X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 10) (614, 10) (154, 10)
